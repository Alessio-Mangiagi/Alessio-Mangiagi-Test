# %%
import pandas as pd

# %%
import numpy as np

# %%
path="C:/Users/Alessio Mangiagi/Desktop/python_conn/beginner_datasets/pokemon.csv"

# %%
dfp=pd.read_csv(path)

# %%
"""Il dataset pokemon.csv contiene un database di Pokémon, con dati quali nome, tipi di attacco, valori di attacco/difesa/eccetera, 
e se sono o meno leggendari. • Verifichiamo la dimensione, un'anteprima e osserviamo i nomi di colonna;
• È verosimile che la prima colonna dovrebbe essere un indice? •
Confrontiamolo con l'indice messo automaticamente da Pandas: combaciano? • Se no, settare la prima colonna come indice.
Quali sono i Pokémon leggendari? • E quali sono i leggendari di tipo 1 Grass? • E leggendari di tipo 1 Ice o Fire? •
Ordiniamo il dataset per la colonna Name; • Trasformiamo Name nell'indice; •
Quali sono i Pokémon della prima generazione con attacco > 50 e HP < 60?
"""
# Out:
# "Il dataset pokemon.csv contiene un database di Pokémon, con dati quali nome, tipi di attacco, valori di attacco/difesa/eccetera, \ne se sono o meno leggendari. • Verifichiamo la dimensione, un'anteprima e osserviamo i nomi di colonna;\n• È verosimile che la prima colonna dovrebbe essere un indice? •\nConfrontiamolo con l'indice messo automaticamente da Pandas: combaciano? • Se no, settare la prima colonna come indice.\nQuali sono i Pokémon leggendari? • E quali sono i leggendari di tipo 1 Grass? • E leggendari di tipo 1 Ice o Fire? •\nOrdiniamo il dataset per la colonna Name; • Trasformiamo Name nell'indice; •\nQuali sono i Pokémon della prima generazione con attacco > 50 e HP < 60?\n"

# %%
dfp
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
dfp.info
# Out:
# <bound method DataFrame.info of        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
dfp.sample(5)
# Out:
#        #               Name    Type 1  Type 2  Total   HP  Attack  Defense  \
# 64    59           Arcanine      Fire     NaN    555   90     110       80
# 591  531  AudinoMega Audino    Normal   Fairy    545  103      60      126
# 171  157         Typhlosion      Fire     NaN    534   78      84       78
# 579  520          Tranquill    Normal  Flying    358   62      77       62
# 337  309          Electrike  Electric     NaN    295   40      45       40
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 64       100       80     95           1      False
# 591       80      126     50           5      False
# 171      109       85    100           2      False
# 579       50       42     65           5      False
# 337       65       40     65           3      False

# %%
dfp.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
dfp.set_index("#",inplace=True)
dfp
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                Bulbasaur    Grass  Poison    318  45      49       49
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
leggendari=dfp["Legendary"] == True
dfp.loc[leggendari]
# Out:
#                     Name    Type 1    Type 2  Total   HP  Attack  Defense  \
# #
# 144             Articuno       Ice    Flying    580   90      85      100
# 145               Zapdos  Electric    Flying    580   90      90       85
# 146              Moltres      Fire    Flying    580   90     100       90
# 150               Mewtwo   Psychic       NaN    680  106     110       90
# 150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190      100
# ..                   ...       ...       ...    ...  ...     ...      ...
# 719              Diancie      Rock     Fairy    600   50     100      150
# 719  DiancieMega Diancie      Rock     Fairy    700   50     160      110
# 720  HoopaHoopa Confined   Psychic     Ghost    600   80     110       60
# 720   HoopaHoopa Unbound   Psychic      Dark    680   80     160       60
# 721            Volcanion      Fire     Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
erba=dfp["Type 1"] == "grass"   
[erba]
# Out:
# [#
#  1      False
#  2      False
#  3      False
#  3      False
#  4      False
#         ...
#  719    False
#  719    False
#  720    False
#  720    False
#  721    False
#  Name: Type 1, Length: 800, dtype: bool]

# %%
fuoco=dfp[(dfp["Type 1"] == "Fire" )&(dfp["Legendary"])] 
fuoco
# Out:
#           Name Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 146    Moltres   Fire  Flying    580   90     100       90      125       85
# 244      Entei   Fire     NaN    580  115     115       85       90       75
# 250      Ho-oh   Fire  Flying    680  106     130       90      110      154
# 485    Heatran   Fire   Steel    600   91      90      106      130      106
# 721  Volcanion   Fire   Water    600   80     110      120      130       90
#
#      Speed  Generation  Legendary
# #
# 146     90           1       True
# 244    100           2       True
# 250     90           2       True
# 485     77           4       True
# 721     70           6       True

# %%
ghiaccio=dfp[(dfp["Type 1"] == "Ice" )&(dfp["Legendary"])]  
ghiaccio
# Out:
#          Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 144  Articuno    Ice  Flying    580  90      85      100       95      125
# 378    Regice    Ice     NaN    580  80      50      100      100      200
#
#      Speed  Generation  Legendary
# #
# 144     85           1       True
# 378     50           3       True

# %%
x=pd.concat([fuoco, ghiaccio])
x
# Out:
#           Name Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 146    Moltres   Fire  Flying    580   90     100       90      125       85
# 244      Entei   Fire     NaN    580  115     115       85       90       75
# 250      Ho-oh   Fire  Flying    680  106     130       90      110      154
# 485    Heatran   Fire   Steel    600   91      90      106      130      106
# 721  Volcanion   Fire   Water    600   80     110      120      130       90
# 144   Articuno    Ice  Flying    580   90      85      100       95      125
# 378     Regice    Ice     NaN    580   80      50      100      100      200
#
#      Speed  Generation  Legendary
# #
# 146     90           1       True
# 244    100           2       True
# 250     90           2       True
# 485     77           4       True
# 721     70           6       True
# 144     85           1       True
# 378     50           3       True

# %%
dfp.sort_values(by="Name")
# Out:
#                           Type 1  Type 2  Total   HP  Attack  Defense  \
# Name
# Abomasnow                  Grass     Ice    494   90      92       75
# AbomasnowMega Abomasnow    Grass     Ice    594   90     132      105
# Abra                     Psychic     NaN    310   25      20       15
# Absol                       Dark     NaN    465   65     130       60
# AbsolMega Absol             Dark     NaN    565   65     150       60
# ...                          ...     ...    ...  ...     ...      ...
# Zoroark                     Dark     NaN    510   60     105       60
# Zorua                       Dark     NaN    330   40      65       40
# Zubat                     Poison  Flying    245   40      45       35
# Zweilous                    Dark  Dragon    420   72      85       70
# Zygarde50% Forme          Dragon  Ground    600  108     100      121
#
#                          Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Name
# ...

# %%
dfp.set_index("Name",inplace=True)
dfp
# Out:
#                         Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur                Grass  Poison    318  45      49       49       65
# Ivysaur                  Grass  Poison    405  60      62       63       80
# Venusaur                 Grass  Poison    525  80      82       83      100
# VenusaurMega Venusaur    Grass  Poison    625  80     100      123      122
# Charmander                Fire     NaN    309  39      52       43       60
# ...                        ...     ...    ...  ..     ...      ...      ...
# Diancie                   Rock   Fairy    600  50     100      150      100
# DiancieMega Diancie       Rock   Fairy    700  50     160      110      160
# HoopaHoopa Confined    Psychic   Ghost    600  80     110       60      150
# HoopaHoopa Unbound     Psychic    Dark    680  80     160       60      170
# Volcanion                 Fire   Water    600  80     110      120      130
#
# ...

# %%
y=dfp.loc[(dfp["HP"]>50)&(dfp["Generation"]==1)]
y
# Out:
#                       Name   Type 1    Type 2  Total   HP  Attack  Defense  \
# #
# 2                  Ivysaur    Grass    Poison    405   60      62       63
# 3                 Venusaur    Grass    Poison    525   80      82       83
# 3    VenusaurMega Venusaur    Grass    Poison    625   80     100      123
# 5               Charmeleon     Fire       NaN    405   58      64       58
# 6                Charizard     Fire    Flying    534   78      84       78
# ..                     ...      ...       ...    ...  ...     ...      ...
# 149              Dragonite   Dragon    Flying    600   91     134       95
# 150                 Mewtwo  Psychic       NaN    680  106     110       90
# 150    MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190      100
# 150    MewtwoMega Mewtwo Y  Psychic       NaN    780  106     150       70
# 151                    Mew  Psychic       NaN    600  100     100      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
z=dfp.loc[(dfp["HP"]<60)&(dfp["Generation"]==1)]
z
# Out:
#            Name  Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1     Bulbasaur   Grass  Poison    318  45      49       49       65       65
# 4    Charmander    Fire     NaN    309  39      52       43       60       50
# 5    Charmeleon    Fire     NaN    405  58      64       58       80       65
# 7      Squirtle   Water     NaN    314  44      48       65       50       64
# 8     Wartortle   Water     NaN    405  59      63       80       65       80
# ..          ...     ...     ...    ...  ..     ...      ...      ...      ...
# 132       Ditto  Normal     NaN    288  48      48       48       48       48
# 133       Eevee  Normal     NaN    325  55      55       50       45       65
# 138     Omanyte    Rock   Water    355  35      40      100       90       55
# 140      Kabuto    Rock   Water    355  30      80       90       55       45
# 147     Dratini  Dragon     NaN    300  41      64       45       50       50
#
# ...

# %%
hp=pd.concat([y, z])
hp
# Out:
#                       Name  Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 2                  Ivysaur   Grass  Poison    405  60      62       63
# 3                 Venusaur   Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur   Grass  Poison    625  80     100      123
# 5               Charmeleon    Fire     NaN    405  58      64       58
# 6                Charizard    Fire  Flying    534  78      84       78
# ..                     ...     ...     ...    ...  ..     ...      ...
# 132                  Ditto  Normal     NaN    288  48      48       48
# 133                  Eevee  Normal     NaN    325  55      55       50
# 138                Omanyte    Rock   Water    355  35      40      100
# 140                 Kabuto    Rock   Water    355  30      80       90
# 147                Dratini  Dragon     NaN    300  41      64       45
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# 2         80       80     60           1      False
# ...
